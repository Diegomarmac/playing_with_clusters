# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
vehicle_df = pd.read_csv('vehicle.csv').dropna()
vehicle_df.head()
# Out:
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0           95         48.0                  83.0         178.0
# 1           91         41.0                  84.0         141.0
# 2          104         50.0                 106.0         209.0
# 3           93         41.0                  82.0         159.0
# 4           85         44.0                  70.0         205.0
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                  72.0                       10          162.0
# 1                  57.0                        9          149.0
# 2                  66.0                       10          207.0
# 3                  63.0                        9          144.0
# 4                 103.0                       52          149.0
#
#    elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 0           42.0                    20.0                        159
# 1           45.0                    19.0                        143
# 2           32.0                    23.0                        158
# 3           46.0                    19.0                        143
# 4           45.0                    19.0                        144
#
#    scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 0            176.0              379.0                      184.0
# 1            170.0              330.0                      158.0
# 2            223.0              635.0                      220.0
# 3            160.0              309.0                      127.0
# 4            241.0              325.0                      188.0
#
#    scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 0                         70.0             6.0              16.0
# 1                         72.0             9.0              14.0
# 2                         73.0            14.0               9.0
# 3                         63.0             6.0              10.0
# 4                        127.0             9.0              11.0
#
#    skewness_about.2  hollows_ratio class
# 0             187.0            197   van
# 1             189.0            199   van
# 2             188.0            196   car
# 3             199.0            207   van
# 4             180.0            183   bus

# %%
pd.value_counts(vehicle_df['class']).plot(kind='bar')
# Out:
# /tmp/ipykernel_3174/448173648.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(vehicle_df['class']).plot(kind='bar')
# <Axes: xlabel='class'>

# %%
pd.value_counts(vehicle_df['class']).hist(bins=300)
# Out:
# /tmp/ipykernel_3174/1228431988.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(vehicle_df['class']).hist(bins=300)
# <Axes: >

# %%
vehicle_df_1 = vehicle_df.drop('class', axis=1)
vehicle_df_1_z = vehicle_df_1.apply(zscore)
vehicle_df_1_z
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 0       0.163231     0.520408              0.060669      0.264970
# 1      -0.322874    -0.619123              0.124067     -0.836393
# 2       1.256966     0.845988              1.518823      1.187734
# 3      -0.079822    -0.619123             -0.002729     -0.300595
# 4      -1.052030    -0.130753             -0.763506      1.068668
# ..           ...          ...                   ...           ...
# 841    -0.079822    -0.944703              0.314261      0.413803
# 842    -0.565926     0.194828              0.124067     -0.181529
# 843     1.500018     1.497149              1.201833      1.574700
# 844    -0.930504    -1.433074             -0.256321     -0.687560
# 845    -1.052030    -1.433074             -1.017098     -1.372192
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                1.283254                 0.299721      -0.198517
# 1               -0.599253                 0.085785      -0.591720
# 2                0.530251                 0.299721       1.162569
# 3                0.153750                 0.085785      -0.742952
# 4                5.173770                 9.285029      -0.591720
# ..                    ...                      ...            ...
# 841              0.279250                -0.128151       0.013207
# 842              0.530251                 0.513657      -0.289256
# 843              0.655752                 0.727593       1.616264
# 844             -0.473753                -0.342087      -1.015169
# 845             -0.850254                -0.769959      -1.468864
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 0         0.129648               -0.217151                   0.766312
# 1         0.514333               -0.606014                  -0.337462
# 2        -1.152637                0.949438                   0.697326
# 3         0.642562               -0.606014                  -0.337462
# 4         0.514333               -0.606014                  -0.268476
# ..             ...                     ...                        ...
# 841      -0.126809               -0.217151                  -0.958335
# 842       0.257876               -0.217151                   0.766312
# 843      -1.409094                1.727163                   1.732113
# 844       1.155476               -0.994877                  -1.648193
# 845       1.924847               -1.383740                  -1.372250
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 0          -0.397397          -0.339014                   0.301676
# 1          -0.590034          -0.618754                  -0.502972
# 2           1.111591           1.122486                   1.415804
# 3          -0.911095          -0.738643                  -1.462359
# 4           1.689501          -0.647299                   0.425468
# ..               ...                ...                        ...
# 841         0.373150          -0.093528                  -0.781504
# 842        -0.493716          -0.401813                   0.054092
# 843         1.272121           1.613458                   0.796844
# 844        -1.071626          -0.961293                  -0.812452
# 845        -1.553218          -1.292414                  -1.338567
#
#      scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 0                      -0.321192       -0.071523          0.371287
# 1                      -0.053505        0.538425          0.147109
# 2                       0.080339        1.555006         -0.413338
# 3                      -1.258099       -0.071523         -0.301249
# 4                       7.307905        0.538425         -0.189159
# ..                           ...             ...               ...
# 841                    -0.053505        0.131793          1.380091
# 842                    -0.053505       -1.088104          0.819644
# 843                    -0.321192       -0.681472         -0.973784
# 844                    -0.856567       -1.291420          1.380091
# 845                     0.080339       -1.088104          0.595466
#
#      skewness_about.2  hollows_ratio
# 0           -0.321809       0.171837
# 1            0.003400       0.442318
# 2           -0.159204       0.036596
# 3            1.629444       1.524243
# 4           -1.460039      -1.721531
# ..                ...            ...
# 841         -0.159204      -0.098644
# 842         -0.484413       0.171837
# 843         -0.321809       0.712800
# 844          0.166004      -0.098644
# 845         -0.484413      -0.774847
#
# [813 rows x 18 columns]

# %%
sc = StandardScaler()

X_standard = sc.fit_transform(vehicle_df_1)
X_standard
# Out:
# array([[ 0.16323063,  0.52040788,  0.06066872, ...,  0.37128716,
#         -0.3218087 ,  0.17183708],
#        [-0.32287376, -0.61912319,  0.12406675, ...,  0.14710858,
#          0.00340009,  0.44231829],
#        [ 1.2569655 ,  0.84598818,  1.51882349, ..., -0.41333788,
#         -0.1592043 ,  0.03659647],
#        ...,
#        [ 1.5000177 ,  1.49714879,  1.20183332, ..., -0.97378433,
#         -0.3218087 ,  0.7127995 ],
#        [-0.93050425, -1.43307395, -0.25632145, ...,  1.38009078,
#          0.16600449, -0.09864413],
#        [-1.05203035, -1.43307395, -1.01709784, ...,  0.59546574,
#         -0.4844131 , -0.77484716]])

# %%
plt.scatter(X_standard[:,0], X_standard[:,1])
plt.show()

# %% [markdown]
# ## Now lets do k-means !!

# %%
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
clusters = range(1,10)
meanDistortions = []

for k in clusters:
    model=KMeans(n_clusters=k)
    model.fit(X_standard)
    prediction=model.predict(X_standard)
    meanDistortions.append(sum(np.min(cdist(X_standard,model.cluster_centers_,'euclidean'),axis=1)) / X_standard.shape[0])

plt.plot(clusters, meanDistortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distorsion promedio')
plt.title('Veamos el metodo del codo')
# Out:
# Text(0.5, 1.0, 'Veamos el metodo del codo')

# %%
kmeans = KMeans(n_clusters=3, n_init = 15, random_state=1234)
kmeans.fit(X_standard)
# Out:
# KMeans(n_clusters=3, n_init=15, random_state=1234)

# %%
centroids = kmeans.cluster_centers_
centroids
# Out:
# array([[ 1.13076532,  1.17094237,  1.19500584,  1.01909505,  0.21505188,
#          0.34250798,  1.27180461, -1.19061224,  1.27548416,  1.09266768,
#          1.22038121,  1.28132727,  1.07954232, -0.02879497,  0.16229031,
#          0.26566456, -0.00535553,  0.18380067],
#        [-0.91987072, -0.52009251, -0.89320752, -1.06435572, -0.50042171,
#         -0.2190738 , -0.7791213 ,  0.86589322, -0.74535635, -0.484632  ,
#         -0.78240328, -0.78341064, -0.38498232,  0.83878747, -0.09524349,
#         -0.30171562, -1.05420601, -1.11069466],
#        [-0.2339617 , -0.57387481, -0.30776905, -0.03041322,  0.2050726 ,
#         -0.11653151, -0.45904181,  0.32506329, -0.48798836, -0.53604446,
#         -0.41380935, -0.46366305, -0.60155031, -0.61924057, -0.06177969,
#          0.01066762,  0.81278556,  0.69897299]])

# %%
centroid_df = pd.DataFrame(centroids, columns = list(X_standard))
# es muy largo como para mostrarlo...

# %%
dataframe_labels = pd.DataFrame(kmeans.labels_ , columns = list(['labels']))
dataframe_labels['labels'] = dataframe_labels['labels'].astype('category')

# %%
dataframe_labeled = vehicle_df_1.join(dataframe_labels)

# %%
dataframe_analysis = (dataframe_labeled.groupby(['labels'])).head(1234)
dataframe_labeled['labels'].value_counts()
# Out:
# /tmp/ipykernel_3174/2810855334.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dataframe_analysis = (dataframe_labeled.groupby(['labels'])).head(1234)
# labels
# 2    297
# 0    251
# 1    232
# Name: count, dtype: int64

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=20, azim=60)
kmeans.fit(vehicle_df_1_z)
labels = kmeans.labels_
ax.scatter(vehicle_df_1_z.iloc[:, 0], vehicle_df_1_z.iloc[:, 1], vehicle_df_1_z.iloc[:, 3],c=labels.astype(float), edgecolor='k')
ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel('Length')
ax.set_ylabel('Height')
ax.set_zlabel('Weight')
ax.set_title('3D plot of KMeans Clustering on vehicles dataset')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 8
#       6 labels = kmeans.labels_
#       7 ax.scatter(vehicle_df_1_z.iloc[:, 0], vehicle_df_1_z.iloc[:, 1], vehicle_df_1_z.iloc[:, 3],c=labels.astype(float), edgecolor='k')
# ----> 8 ax.w_xaxis.set_ticklabels([])
#       9 ax.w_yaxis.set_ticklabels([])
#      10 ax.w_zaxis.set_ticklabels([])
#
# AttributeError: 'Axes3D' object has no attribute 'w_xaxis'
